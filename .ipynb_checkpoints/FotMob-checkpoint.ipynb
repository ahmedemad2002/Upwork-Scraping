# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
browser = webdriver.Chrome(executable_path=r"D:\AE\Programs\chromedriver.exe")
# Out:
# <ipython-input-78-316644bdac9b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=r"D:\AE\Programs\chromedriver.exe")

# %%
browser.get('https://www.fotmob.com/')

# %%
leagues = browser.find_elements('xpath', "//a[@class='css-fm8es-LeagueEntryCSS emvu2jr4']")
league_name = [l.text for l in leagues]
league_links = [l.get_attribute('href') for l in leagues]

# %%
for link in league_links:
    browser.get(link)
    time.sleep(2)
    matches_link=browser.find_elements('xpath', "//a[@class='css-1xjasri-NavLinkCSS-applyMediumHover-navCommonStyles-navStyles eyuy2lc0']")[2].get_attribute('href')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="066d1954-96a7-4a6d-918c-3de5e6ffd2a1")>, <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="a59ed1aa-cf6f-458e-9f7e-3c5128aaae49")>, <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="a04ec425-210f-4792-839b-a8b56f5bcea5")>, <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="776aa674-8b36-456b-80e9-c9b8d2b54d6f")>, <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="a6018948-6a4e-4734-8895-1a4593a1f81d")>]
# ['News', 'Table', 'Matches', 'Stats', 'Transfers']
# ...

# %%
options = browser.find_elements('xpath', "//a[@class='css-1aqyd89-MatchWrapper ew7iiy61']")
options
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="09a15f7b-a5fa-414e-8f52-761604915554")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="5aa38061-48d7-41c6-99ed-cc00d31430c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="9bca2fa5-cbe9-43de-acd1-8eebe442d9ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="06de264b-66de-42f0-b038-c974682da9ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="807f158a-8db2-4c97-bdbb-b1ccba8d7b47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4aba91b06d90b82958604109936329a9", element="3d93f5cc-b20e-4623-aea4-21595281b1db")>,
# ...

# %%
match_links = [o.get_attribute('href') for o in options]
match_links
# Out:
# ['https://www.fotmob.com/match/3901110/matchfacts/west-ham-united-vs-brentford',
#  'https://www.fotmob.com/match/3901105/matchfacts/liverpool-vs-leicester-city',
#  'https://www.fotmob.com/match/4054117/matchfacts/smouha-sc-vs-ghazl-al-mehalla',
#  'https://www.fotmob.com/match/4054116/matchfacts/national-bank-vs-al-mokawloon-al-arab',
#  'https://www.fotmob.com/match/3918081/matchfacts/getafe-vs-mallorca',
#  'https://www.fotmob.com/match/3918087/matchfacts/cadiz-vs-almeria',
#  'https://www.fotmob.com/match/3918080/matchfacts/celta-vigo-vs-sevilla',
#  'https://www.fotmob.com/match/3918085/matchfacts/real-valladolid-vs-real-madrid',
#  'https://www.fotmob.com/match/4019520/matchfacts/myanmar-vs-laos',
#  'https://www.fotmob.com/match/4019521/matchfacts/singapore-vs-vietnam',
#  'https://www.fotmob.com/match/3978765/matchfacts/western-united-fc-vs-brisbane-roar-fc',
#  'https://www.fotmob.com/match/3981932/matchfacts/hebei-fc-vs-henan-songshan-longmen',
# ...

# %%
for match in match_links:
    browser.get(match)
    time.sleep(2)
    print([x.text for x in browser.find_elements('xpath', "//span[@class='css-1pb0mb5-LineupPlayerText eo59uzm0']")])
    print('\n\n')
# Out:
# ['1Fabianski', '33Emerson', '24Kehrer', '15Dawson', '5Coufal', '41Rice', '28Soucek', '22Benrahma', '11Paquetá', '8Fornals', '20Bowen', '19Mbeumo', '17Toney', '30Roerslev', '8Jensen', '6Nørgaard', '27Janelt', '3Henry', '13Zanka', '5Pinnock', '16Mee', '1Raya']
#
#
#
# ['1Becker', '26Robertson', '4van Dijk', '32Matip', '66Alexander-Arnold', '6Thiago', '3Fabinho', '14Henderson', '15Oxlade-Chamberlain', '27Nunez', '11Salah', '20Daka', '17Pérez', '7Barnes', '8Tielemans', '25Ndidi', '22Dewsbury-Hall', '27Castagne', '3Faes', '18Amartey', '33Thomas', '1Ward']
#
#
#
# []
#
#
#
# []
#
#
#
# ['13Soria', '6Duarte', '23Mitrovic', '2Djené', '21Iglesias', '5Milla', '20Maksimovic', '11Alena', '22Suarez', '10Ünal', '19Mayoral', '7Muriqi', '19Lee', '15Maffeo', '10Sánchez', '12Baba', '14Rodriguez', '18Costa', '2Nastasic', '21Raillo', '6Copete', '1Rajkovic']
#
#
#
# ...

# %%
matches = [o.text for o in options]

# %%
[match.replace('\n', ' ') for match in matches]
# Out:
# ['West Ham 9:45 PM Brentford',
#  'Liverpool 10:00 PM Leicester',
#  'Smouha SC 5:00 PM Ghazl Al Mehalla',
#  'National Bank 7:00 PM Al Mokawloon Al Arab',
#  'Getafe 6:00 PM Mallorca',
#  'Cadiz 8:15 PM Almeria',
#  'Celta Vigo 8:15 PM Sevilla',
#  'Real Valladolid 10:30 PM Real Madrid',
#  'Myanmar 12:00 PM Laos',
#  'Singapore 2:30 PM Vietnam',
#  'Western United FC 10:45 AM Brisbane Roar FC',
#  'Hebei FC 9:00 AM Henan Songshan Longmen',
#  'Shanghai Shenhua 9:00 AM Shenzhen FC',
#  'Willem II 1:00 PM Excelsior',
#  'FC Volendam 2:00 PM NAC Breda',
#  'FC Groningen 3:00 PM Almere City FC',
#  'Westerlo 3:00 PM Sparta Rotterdam',
#  'Juventus 3:30 PM Standard Liege',
#  'Atalanta 4:00 PM Crema',
#  'PSV Eindhoven 7:15 PM Milan',
#  'Birmingham 9:45 PM Hull',
#  'Norwich 9:45 PM Reading',
#  'Stoke 9:45 PM Burnley',
#  'Swansea 9:45 PM Watford',
#  'Derby 9:45 PM Cambridge',
#  'Lincoln 9:45 PM Bolton',
#  'Newport 9:45 PM Leyton Orient',
#  'Stevenage 9:45 PM Crawley',
# ...

# %%
browser.get(link_of_best)

# %%
browser.get(browser.find_elements('xpath', "//a[@title='Top Movies']")[0].get_attribute('href'))
